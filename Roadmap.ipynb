# %%
import pandas as pd
import numpy as np
from typing import List, Dict
from crr_labels.roadmap import roadmap
import matplotlib.pyplot as plt

# %%
enhancers, promoters = roadmap(
    ["HelaS3", "GM12878"],
    200
)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: PerformanceWarning: indexing past lexsort depth may impact performance.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:635: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
enhancers
# Out:
#       chromosome      start        end strand  GM12878  HELAS3
# 0           chr1     763000     763200      .        1       0
# 1           chr1     843800     844000      .        1       0
# 2           chr1     880400     880600      .        0       1
# 3           chr1     937800     938000      .        0       1
# 4           chr1     940800     941000      .        0       1
# 5           chr1     942200     942400      .        0       1
# 6           chr1     947600     947800      .        0       1
# 7           chr1     947800     948000      .        0       1
# 8           chr1     947900     948100      .        1       0
# 9           chr1     974200     974400      .        1       0
# 10          chr1     984400     984600      .        1       0
# 11          chr1     985200     985400      .        1       0
# 12          chr1     998600     998800      .        1       0
# 13          chr1    1000000    1000200      .        1       0
# ...
